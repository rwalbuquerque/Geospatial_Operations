# %%
import geopandas as gpd
import pandas as pd
from glob import glob
import statistics
import numpy as np
import rasterio as rio
from shapely.geometry import Polygon

# %%
# Import preview and test shapefiles for both trees and non-trees classes
shapePrev_Trees = gpd.read_file("C:/Projetos/Vant_Rondonia_Embrapa/03Dez2019/Deep_Learning_Arvores/Acuracia/Union_CNN03Dez_CNN09Dez.shp")
shapeTest_Trees = gpd.read_file("C:/Projetos/Vant_Rondonia_Embrapa/03Dez2019/Deep_Learning_Arvores/Acuracia/03Dez2019_Arvores_Teste.shp")

# Intersection between preview and test of trees classes: shapePrev_Trees and shapeTest_Trees
trees_intersect = gpd.overlay(shapePrev_Trees, shapeTest_Trees, how = "intersection")

trees_intersect.plot(cmap='cividis', alpha=0.7, edgecolor='black')
# Out:
# <AxesSubplot:>

# %%
# Calculate True-Positive (TP): if trees_intersect area is greater than 50% of shapeTest_Trees area, count as TP
TP = []
for feature in shapePrev_Trees["geometry"]:
  # Transform feature in geodataframe
  df1 = gpd.geoseries.GeoSeries(feature)
  df1 = gpd.GeoDataFrame({'geometry': df1})
  df1.crs = {'init': 'epsg:32720'}
  # Select the test polygon that overlaps the preview feature
  overlap_test  = gpd.sjoin(shapeTest_Trees, df1, how='inner',op='intersects')
  if overlap_test.empty:
    pass
  else:
    # Overlay the join of both shapefiles to transform overlap_test on GeoDataFrame to make it possible for geoprocessing
    # Note that "intersection" is the operation that keeps only the intersection between preview and test shapefiles
    intersection = gpd.overlay(overlap_test, df1, how = "intersection")
    # Dissolve using unary_union
    geoms1 = intersection.geometry.unary_union
    # convert geoms to geodataframe to make it possible for geoprocessing
    df2 = gpd.geoseries.GeoSeries(geoms1)
    df2 = gpd.GeoDataFrame({'geometry': df2})
    df2.crs = {'init': 'epsg:32720'}
    # Select the test polygon that overlaps the intersection (variable geoms1) feature
    overlap_test2  = gpd.sjoin(shapeTest_Trees, df2, how='inner',op='intersects')
    # Note that "union" is the operation that keeps the spatial join of overlap_test on the original test polygon delineation
    union = gpd.overlay(overlap_test2, df2, how = "union")
    # Dissolve using unary_union
    geoms2 = union.geometry.unary_union
    # Compare if intersection between preview and test of tree classes are greater than 50% of corresponding test tree class polygon
    if geoms1.area > (geoms2.area)/2:
      TP.append(feature)
      #print(TP)
      # The below plot can be used if you wish to visually check intersect polygon (df1 variable) or test polygon (overlap_test) that were counted as TP
      #overlap_test.plot(cmap='cividis', alpha=0.7, edgecolor='black')

# Get the amount of TP by checking TP lenght
print("TP = ", len(TP))
df2 = gpd.geoseries.GeoSeries(TP)
df2 = gpd.GeoDataFrame({'geometry': df2})
df2.crs = {'init': 'epsg:32720'}
df2.to_file("C:/Projetos/Vant_Rondonia_Embrapa/03Dez2019/Deep_Learning_Arvores/Acuracia/TruePositives.shp")
df2.plot(cmap='cividis', alpha=0.7, edgecolor='black')
# Out:
# C:\Users\Rafael\anaconda3\envs\rasterio_gpd\lib\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# C:\Users\Rafael\anaconda3\envs\rasterio_gpd\lib\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# ...

# %%
# Extract bounding box of the polygons on the TP shapefile

TP_shp = gpd.read_file("C:/Projetos/Vant_Rondonia_Embrapa/03Dez2019/Deep_Learning_Arvores/Acuracia/TruePositives.shp")

xy1 = []
xy2 = []
# Print just to see how to plot x and y data
print(np.array(TP_shp["geometry"].bounds)[0,0])
print(np.array(TP_shp["geometry"].bounds)[0,1])
i=0
# Loop over all feature polygons in the shapefile
for feature in TP_shp.length:
  # Get every possible combination between maximum and minimum x and y data
  xy1.append([np.array(TP_shp["geometry"].bounds)[i,0], np.array(TP_shp["geometry"].bounds)[i,1]])
  xy1.append([np.array(TP_shp["geometry"].bounds)[i,2], np.array(TP_shp["geometry"].bounds)[i,1]])
  xy1.append([np.array(TP_shp["geometry"].bounds)[i,2], np.array(TP_shp["geometry"].bounds)[i,3]])
  xy1.append([np.array(TP_shp["geometry"].bounds)[i,0], np.array(TP_shp["geometry"].bounds)[i,3]])
  # Insert the polygon bounding box on a list containing coordinates grouped by polygon bounding box on each element of the list
  xy2.append(Polygon(xy1))
  # Erase content of the first list to garantee that different polygons will be disjointed
  xy1 = []
  # Head to the next polygon feature of the shapefile
  i=i+1

# Convert polygon list to geodataframe
df1 = gpd.geoseries.GeoSeries(xy2)
df1 = gpd.GeoDataFrame({'geometry': df1})
df1.crs = {'init': 'epsg:32720'}
df1.to_file("C:/Projetos/Vant_Rondonia_Embrapa/03Dez2019/Deep_Learning_Arvores/Acuracia/BB_TP.shp")
df1.plot(cmap='cividis', alpha=0.7, edgecolor='black')
# Out:
# 297521.9981139011
# 8943753.651103923
# C:\Users\Rafael\anaconda3\envs\rasterio_gpd\lib\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# <AxesSubplot:>

# %%
# Extract bounding box of the polygons on the Test shapefile

Test_shp = gpd.read_file("C:/Projetos/Vant_Rondonia_Embrapa/03Dez2019/Deep_Learning_Arvores/Acuracia/03Dez2019_Arvores_Teste.shp")

xy1 = []
xy2 = []
# Print just to see how to plot x and y data
print(np.array(Test_shp["geometry"].bounds)[0,0])
print(np.array(Test_shp["geometry"].bounds)[0,1])
i=0
# Loop over all feature polygons in the shapefile
for feature in Test_shp.length:
  # Get every possible combination between maximum and minimum x and y data
  xy1.append([np.array(Test_shp["geometry"].bounds)[i,0], np.array(Test_shp["geometry"].bounds)[i,1]])
  xy1.append([np.array(Test_shp["geometry"].bounds)[i,2], np.array(Test_shp["geometry"].bounds)[i,1]])
  xy1.append([np.array(Test_shp["geometry"].bounds)[i,2], np.array(Test_shp["geometry"].bounds)[i,3]])
  xy1.append([np.array(Test_shp["geometry"].bounds)[i,0], np.array(Test_shp["geometry"].bounds)[i,3]])
  # Insert the polygon bounding box on a list containing coordinates grouped by polygon bounding box on each element of the list
  xy2.append(Polygon(xy1))
  # Erase content of the first list to garantee that different polygons will be disjointed
  xy1 = []
  # Head to the next polygon feature of the shapefile
  i=i+1

# Convert polygon list to geodataframe
df1 = gpd.geoseries.GeoSeries(xy2)
df1 = gpd.GeoDataFrame({'geometry': df1})
df1.crs = {'init': 'epsg:32720'}
df1.to_file("C:/Projetos/Vant_Rondonia_Embrapa/03Dez2019/Deep_Learning_Arvores/Acuracia/BB_test.shp")
df1.plot(cmap='cividis', alpha=0.7, edgecolor='black')
# Out:
# 297652.6063871579
# 8943644.735031683
# C:\Users\Rafael\anaconda3\envs\rasterio_gpd\lib\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# <AxesSubplot:>

# %%
# Import bounding boxes of TruePositives and test shapefiles for trees classes
shapeTP_TreesBB = gpd.read_file("C:/Projetos/Vant_Rondonia_Embrapa/03Dez2019/Deep_Learning_Arvores/Acuracia/BB_TP.shp")
shapeTest_TreesBB = gpd.read_file("C:/Projetos/Vant_Rondonia_Embrapa/03Dez2019/Deep_Learning_Arvores/Acuracia/BB_test.shp")

# Intersection between preview and test of trees classes: shapePrev_Trees and shapeTest_Trees
trees_intersect = gpd.overlay(shapeTP_TreesBB, shapeTest_TreesBB, how = "intersection")

# Union between TruePositives and test of trees classes: shapeTP_Trees and shapeTest_Trees
trees_union = gpd.overlay(shapeTP_TreesBB, shapeTest_TreesBB, how = "union")

#trees_intersect.plot(cmap='cividis', alpha=0.7, edgecolor='black')
trees_union.plot(cmap='cividis', alpha=0.7, edgecolor='black')
# Out:
# <AxesSubplot:>

# %%
# Calculate IoU index according to Bounding Boxes

# Intersection between TruePositives and test of trees classes: shapeTP_Trees and shapeTest_Trees
trees_intersect = gpd.overlay(shapeTP_TreesBB, shapeTest_TreesBB, how = "intersection")

# Union between TruePositives and test of trees classes: shapeTP_Trees and shapeTest_Trees
trees_union = gpd.overlay(shapeTP_TreesBB, shapeTest_TreesBB, how = "union")

iou = []
precision = []
recall = []
i=0
for feature in shapeTP_TreesBB["geometry"]:
  # Transform feature in geodataframe
  df1 = gpd.geoseries.GeoSeries(feature)
  df1 = gpd.GeoDataFrame({'geometry': df1})
  df1.crs = {'init': 'epsg:32720'}
  # Spatial join of TruePositives and test to select the intersect polygon that overlaps the test feature
  overlap_intersect  = gpd.sjoin(shapeTest_TreesBB, df1, how='inner',op='intersects')
  if overlap_intersect.empty:
    intersect.append(0)
    test.append(feature.area)
    #print("Empty feature intersection")
  else:
    # Overlay the intersection of variable "overlap_intersect" on GeoDataFrame to allow its geoprocessing
    # Note that "union" is the operation that unites TruePositives and test bounding box
    union1 = gpd.overlay(overlap_intersect, df1, how = "union")
    # Dissolve using unary_union
    geoms1 = union1.geometry.unary_union
    # Print to check by hand if calculation is correct
    #print("Union area = ", geoms1.area)
    # Plot if you want to check what the algorithm is doing
    #df3 = gpd.geoseries.GeoSeries(geoms1)
    #df3 = gpd.GeoDataFrame({'geometry': df3})
    #df3.crs = {'init': 'epsg:32721'}
    #df3.plot(cmap='cividis', alpha=0.7, edgecolor='black')
    # Overlay the intersection of both shapefiles to transform overlap_intersect on GeoDataFrame to make it possible to calculate the area
    # Get intersection between feature polygon ("df1" variable) and test bounding box
    intersection1 = gpd.overlay(overlap_intersect, df1, how = "intersection")
    # Dissolve using unary_union
    geoms2 = intersection1.geometry.unary_union
    # Print to check by hand if calculation is correct
    #print("Intersection area = ", geoms2.area)
    # Print to check by hand if calculation is correct
    iou.append(geoms2.area/geoms1.area)
    precision.append(geoms2.area/feature.area)
    #print("IoU =", geoms2.area/geoms1.area)
    # Get test bounding box by selecting it according to intersection area
    df2 = gpd.geoseries.GeoSeries(geoms2)
    df2 = gpd.GeoDataFrame({'geometry': df2})
    df2.crs = {'init': 'epsg:32720'}
    overlap_intersect2  = gpd.sjoin(shapeTest_TreesBB, df2, how='inner',op='intersects')
    # Note that "union" is the operation that unites TruePositives and test bounding box
    union2 = gpd.overlay(overlap_intersect2, df2, how = "union")
    # Dissolve using unary_union
    geoms3 = union2.geometry.unary_union
    recall.append(geoms2.area/geoms3.area)
    i=i+1
    
print("Total overlaps (TP): ", i)
print("Total identified trees: ", i/len(Test_shp))
print("Total identified trees: ", i/len(shapeTest_TreesBB))
# Check if crown delineation is correct. It happens when IoU <0.5 == False
print("Total of correctly delineated tree crowns: ", (sum(j >= 0.5 for j in iou))/i)
print("IoU average =", statistics.mean(iou))
print("Precision average =", statistics.mean(precision))
print("Recall average =", statistics.mean(recall))
# Out:
# C:\Users\Rafael\anaconda3\envs\rasterio_gpd\lib\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# C:\Users\Rafael\anaconda3\envs\rasterio_gpd\lib\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# ...
